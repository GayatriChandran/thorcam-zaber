# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pypolar.fresnel as fresnel
# %config InlineBackend.figure_format = 'retina'

# %%
file_name = 'data/09-14-2024/refl-air-09-14-2024-01.csv'                                   # Input file name
df = pd.read_csv(file_name)
# fig, axs = plt.subplots(1, 1, layout='constrained', sharex=True)
df.plot(x="Stage", y="Intensity", alpha=0.5, style='.-')
# axs[0].set_xlabel("Stage (mm)")
# axs[0].set_ylabel("Sum")
# ax.set_xlim([2.3, 7.55])
# ax.set_ylim([0, 30])
# ax.set_title(file_name)                                         # Plot
plt.
# Out:
# <Axes: xlabel='Stage'>
